# %%
True
False
# Out:
# False

# %%
# 비교연산자
3 > 1
# Out:
# True

# %%
# 숫자가 같은지 다른지 비교
print(10 == 10)
print(10 != 5)
# Out:
# True
# True

# %%
print("Python" == "Python")
print("Python" == "python")
# Out:
# True
# False

# %%
# 부등호 사용하기
print(10 > 20)
print(10 < 20)
print(10 >= 20)
print(10 <= 20)
# Out:
# False
# True
# False
# True

# %%
print(1 == 1.0)
# print(1 is 1.0)
print(id(1))
print(id(1.0))
# Out:
# True
# 140706262017144
# 1900230100688

# %%
# 논리연산자 사용하기

print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
not True and False or not False
# Out:
# True

# %%
# 논리연산자와 비교연산자를 함께 사용하기

print(10 == 10 and 10 != 5)
print(10 > 5 or 10 < 3)
print(not 10 > 5)
print(not 1 is 1.0)
# Out:
# True
# True
# False
# True
# <>:6: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:6: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_2592\3683134892.py:6: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(not 1 is 1.0)

# %%
# c / d / b, c / d

# 연습문제
# korean = 92
# english = 47
# mathmatics = 86
# science = 81

# print (korean >= 50 and english >= 50 and mathmatics >= 50 and science >= 50)

# 심사문제
# 국어 >= 90 / 영어 > 80 / 수학 > 85 / 과학 >= 80
korean, english, mathmatics, science = map(int, input().split())
print(korean >= 90 and english > 80 and mathmatics > 85 and science >= 80)
# Out:
# False
