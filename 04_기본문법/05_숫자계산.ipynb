# %%
# 사칙연산
1 + 1
# Out:
# 2

# %%
"1" + "1"
# Out:
# '11'

# %%
1 - 2
# Out:
# -1

# %%
5 / 2
# Out:
# 2.5

# %%
4 / 2
# Out:
# 2.0

# %%
# 소수점 이하를 버리는 연산자 // (몫)
print(6 // 2)
print(4 // 2)
# Out:
# 3
# 2

# %%
# 나머지를 구하는 연산자 %
5 % 2
7 % 3
# Out:
# 1

# %%
# 거듭제곱을 구하는 연산자 **
2 ** 10
10 ** 10
# Out:
# 10000000000

# %%
# 값을 정수로 만들기
int(3.3)
int(5 / 2)
int('1')
# Out:
# 1

# %%
# 객체의 자료형 알아내기

type(10)
type('1')
# Out:
# str

# %%
# 실수 계산하기
3.5 + 2.1
# Out:
# 5.6

# %%
# 실수와 정수를 함께 계산하면
4.2 + 5
# Out:
# 9.2

# %%
# 값을 실수로 만들기
print(float(5))
print(float(1 + 2))
print(float('5.3'))
# Out:
# 5.0
# 3.0
# 5.3

# %%
# 괄호 사용하기
35 + 1 * 2
# Out:
# 37

# %%
(35 + 1) * 2
# Out:
# 72

# %%
# 연습문제
# 0.2467 * 도로와의거리(m) + 4.159

int(0.2467 * 12 + 4.159)

# %%
# 심사문제
# '왜곡': AP * 0.6 + 225

AP = 102
AP * 0.6 + 225
