# %%
# 세미콜론
print('Hello World')
# Out:
# Hello World

# %%
print('hello'); print(1234)
# Out:
# hello
# 1234

# %%
# 한 줄 주석
# 출력하라
print('hello world')
# Out:
# hello world

# %%
# 블록 주석
# print('hello world')
# print('hello world')
# print('hello world')

# %%
# 들여쓰기
a = 5
if a == 10:
    print("10입니다")
        print("5입니다")
# Out:
#   Cell In[19], line 5
#     print("5입니다")
#     ^
# IndentationError: unexpected indent
