# %%
# 리스트에 요소 하나 추가하기
a = [10, 20, 30]
a.append(500)
a
len(a)
# Out:
# 4

# %%
a = []
a.append(10)
print(a)
# Out:
# [10]

# %%
text = 'hello'
text.append('c')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 text = 'hello'
# ----> 2 text.append('c')
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# 리스트 안에 리스트 추가하기
a = [10, 20, 30]
a.append([500, 600])
len(a)
# Out:
# 4

# %%
# 리스트 확장하기
a = [10, 20, 30]
a.extend([100, 200])
print(a)
# Out:
# [10, 20, 30, 100, 200]

# %%
# 리스트의 특정 인덱스에 요소 추가하기
a = [10, 20, 30]
a.insert(-1, 300)
print(a)

a = [10, 20, 30]
a.insert(0, 500)
a
# Out:
# [10, 20, 300, 30]
# [500, 10, 20, 30]

# %%
a = [10, 20, 30]
a.insert(len(a), 500)
a
# Out:
# [10, 20, 30, 500]

# %%
a = [10, 20, 30]
a.insert(1, [500, 600])
a
# Out:
# [10, [500, 600], 20, 30]

# %%
a = [10, 20, 30]
a[1:1] = [500, 600]
# a.insert(1, [500, 600])
a
# Out:
# [10, 500, 600, 20, 30]

# %%
# 리스트의 특정 인덱스의 요소를 삭제하기
a = [10, 20, 30]
print(a.pop(1))
print(a)
# Out:
# 20
# [10, 30]

# %%
a = [10, 20, 30]
del a[1]
a
# Out:
# [10, 30]

# %%
# 리스트에서 특정 값을 찾아서 삭제하기
a = [10, 20, 30]
a.remove(20)
a
# Out:
# [10, 30]

# %%
a = [10, 20, 30, 20]
a.remove(20)
print(a)
a.remove(20)
print(a)
# Out:
# [10, 30, 20]
# [10, 30]
